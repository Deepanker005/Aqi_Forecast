# %%
import pandas as pd
import numpy as np

# %%
AQI=pd.read_csv("AirQualityUCI.csv")

# %%
AQI.head(5)
# Out:
#                                                                                                             Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;
# 10/03/2004;18.00.00;2            6;1360;150;11                 9;1046;166;1056;113;1692;1268;13 6;48 9;0                                                7578;;
# 10/03/2004;19.00.00;2;1292;112;9 4;955;103;1174;92;1559;972;13 3;47                             7;0  7255;;                                                NaN
# 10/03/2004;20.00.00;2            2;1402;88;9                   0;939;131;1140;114;1555;1074;11  9;54 0;0                                                7502;;
# 10/03/2004;21.00.00;2            2;1376;80;9                   2;948;172;1092;122;1584;1203;11  0;60 0;0                                                7867;;
# ...

# %% [markdown]
# **Looking at the data it is seperated by Semicolon instead of commas so mentioning that and reading the data again**

# %%
AQI=pd.read_csv("AirQualityUCI.csv", sep=";", decimal=",")#after first running the code I found that most of the values had comma instead of a decimal for decimal values I put in the third parameter of read csv

# %%
AQI.head(5)
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# ...

# %%
# Dropping the last Two columns from AQI dataframe
AQI=AQI.iloc[:,:-2]

# %%
AQI.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
AQI.tail()
# Out:
#      Date Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 9466  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9467  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9468  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9469  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9470  NaN  NaN     NaN          NaN       NaN       NaN            NaN
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)   T  RH  AH
# 9466      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9467      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9468      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9469      NaN           NaN      NaN           NaN          NaN NaN NaN NaN
# 9470      NaN           NaN      NaN           NaN          NaN NaN NaN NaN

# %%
AQI.shape
# Out:
# (9471, 15)

# %% [markdown]
# **9356 Represent the last row in the dataset and rest of rows are just NULL**

# %%
AQI.loc[[9356]]
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9356        816.0  28.5  13.1  0.5028

# %%
AQI.loc[9357:]
# Out:
#      Date Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 9357  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9358  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9359  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9360  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9361  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# ...   ...  ...     ...          ...       ...       ...            ...
# 9466  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9467  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9468  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9469  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9470  NaN  NaN     NaN          NaN       NaN       NaN            NaN
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)   T  RH  AH
# ...

# %%
AQI=AQI.head(9357)# to store only first 9357 rows in dataframe

# %%
AQI.tail()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9352       1729.0  21.9  29.3  0.7568
# 9353       1269.0  24.3  23.7  0.7119
# 9354       1092.0  26.9  18.3  0.6406
# ...

# %%
AQI.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   str
#  1   Time           9357 non-null   str
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: float64(13), str(2)
# memory usage: 1.1 MB

# %%
#Checking the total number of null values in AQI
AQI.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %% [markdown]
# //https://archive.ics.uci.edu/dataset/360/air+quality
#
# According to the dataset link all the null values are -200 thus we need to substitute those values with NAN so python can read it

# %%
# Counting the -200 values in data

AQI.isin([-200]).sum(axis=0)
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %% [markdown]
# **Handling the Missing values**

# %%
AQI=AQI.replace(to_replace=-200,value=np.nan)# Replacing -200 with nan

# %%
AQI.isin([-200]).sum(axis=0)
AQI.isnull().sum()
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %%
# Isolate the columns you want to calculate (excluding Date, Time, and ghost columns)
numeric_cols = []

# Loop through every single column name currently in the dataset
for col in AQI.columns:
    
    #Check our two conditions:
    #    - Is it NOT the 'Date' or 'Time' column?
    #    - Does the name NOT start with 'Unnamed'?
    if col not in ['Date', 'Time'] and not col.startswith('Unnamed'):
        
        # 4. If both conditions are true, add this column name to our list
        numeric_cols.append(col)

numeric_cols
# Out:
# ['CO(GT)',
#  'PT08.S1(CO)',
#  'NMHC(GT)',
#  'C6H6(GT)',
#  'PT08.S2(NMHC)',
#  'NOx(GT)',
#  'PT08.S3(NOx)',
#  'NO2(GT)',
#  'PT08.S4(NO2)',
#  'PT08.S5(O3)',
#  'T',
#  'RH',
#  'AH']

# %%
AQI[numeric_cols].mean()
# Out:
# CO(GT)              2.152750
# PT08.S1(CO)      1099.833166
# NMHC(GT)          218.811816
# C6H6(GT)           10.083105
# PT08.S2(NMHC)     939.153376
# NOx(GT)           246.896735
# PT08.S3(NOx)      835.493605
# NO2(GT)           113.091251
# PT08.S4(NO2)     1456.264598
# PT08.S5(O3)      1022.906128
# T                  18.317829
# RH                 49.234201
# AH                  1.025530
# dtype: float64

# %%
AQI[numeric_cols] = AQI[numeric_cols].fillna(AQI[numeric_cols].interpolate(method='linear')) #Now calculate the Interpolate of the DATA in those columns, and fill the NaNs

# %%
AQI.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
AQI.tail()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9352  04/04/2005  10.00.00     3.1       1314.0     275.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0     275.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0     275.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0     275.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0     275.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 9352       1729.0  21.9  29.3  0.7568
# 9353       1269.0  24.3  23.7  0.7119
# 9354       1092.0  26.9  18.3  0.6406
# ...

# %% [markdown]
# **Forecasting With The FB Prophet Model Or Algorithm**

# %% [markdown]
# https://facebook.github.io/prophet/docs/quick_start.html

# %%
# Converting date to Datetime format

AQI['Date'] = pd.to_datetime(AQI['Date'], format='%d/%m/%Y')

# %%
AQI['Date']
# Out:
# 0      2004-03-10
# 1      2004-03-10
# 2      2004-03-10
# 3      2004-03-10
# 4      2004-03-10
#           ...
# 9352   2005-04-04
# 9353   2005-04-04
# 9354   2005-04-04
# 9355   2005-04-04
# 9356   2005-04-04
# Name: Date, Length: 9357, dtype: datetime64[us]

# %%
AQI.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0 2004-03-10  18.00.00     2.6       1360.0     150.0      11.9
# 1 2004-03-10  19.00.00     2.0       1292.0     112.0       9.4
# 2 2004-03-10  20.00.00     2.2       1402.0      88.0       9.0
# 3 2004-03-10  21.00.00     2.2       1376.0      80.0       9.2
# 4 2004-03-10  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
AQI['Time']=AQI['Time'].apply(lambda x:x.replace('.',':'))

# %%
AQI['Time']
# Out:
# 0       18:00:00
# 1       19:00:00
# 2       20:00:00
# 3       21:00:00
# 4       22:00:00
#           ...
# 9352    10:00:00
# 9353    11:00:00
# 9354    12:00:00
# 9355    13:00:00
# 9356    14:00:00
# Name: Time, Length: 9357, dtype: str

# %%
# Combining date and Time to make 1 dataframe

dateTime=pd.concat([AQI['Date'],AQI['Time']],axis=1)
dateTime.head()
# Out:
#         Date      Time
# 0 2004-03-10  18:00:00
# 1 2004-03-10  19:00:00
# 2 2004-03-10  20:00:00
# 3 2004-03-10  21:00:00
# 4 2004-03-10  22:00:00

# %%
dateTime['ds']=dateTime['Date'].astype(str)+" "+dateTime['Time'].astype(str)

# %%
dateTime.head()
# Out:
#         Date      Time                   ds
# 0 2004-03-10  18:00:00  2004-03-10 18:00:00
# 1 2004-03-10  19:00:00  2004-03-10 19:00:00
# 2 2004-03-10  20:00:00  2004-03-10 20:00:00
# 3 2004-03-10  21:00:00  2004-03-10 21:00:00
# 4 2004-03-10  22:00:00  2004-03-10 22:00:00

# %%
NewData=pd.DataFrame() #Making new dataframe to add date time ds and y as RH here we could have taken any of the 13 features as RH

# %%
NewData['ds']=pd.to_datetime(dateTime['ds'])

# %%
NewData.head()
# Out:
#                    ds
# 0 2004-03-10 18:00:00
# 1 2004-03-10 19:00:00
# 2 2004-03-10 20:00:00
# 3 2004-03-10 21:00:00
# 4 2004-03-10 22:00:00

# %%
NewData['ds'].dtype
# Out:
# dtype('<M8[us]')

# %%
NewData['y']=AQI['RH']

# %%
NewData.head()
# Out:
#                    ds     y
# 0 2004-03-10 18:00:00  48.9
# 1 2004-03-10 19:00:00  47.7
# 2 2004-03-10 20:00:00  54.0
# 3 2004-03-10 21:00:00  60.0
# 4 2004-03-10 22:00:00  59.6

# %% [markdown]
# **Apply FB Prophet Model to NewData here**

# %%
from prophet import Prophet


model = Prophet()
model.fit(NewData)
# Out:
# 14:18:23 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:24 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=365, freq='h')
future.tail()
# Out:
#                       ds
# 9717 2005-04-19 15:00:00
# 9718 2005-04-19 16:00:00
# 9719 2005-04-19 17:00:00
# 9720 2005-04-19 18:00:00
# 9721 2005-04-19 19:00:00

# %%
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                       ds       yhat  yhat_lower  yhat_upper
# 9717 2005-04-19 15:00:00  32.476073   16.906362   48.664236
# 9718 2005-04-19 16:00:00  32.904100   17.233202   48.749243
# 9719 2005-04-19 17:00:00  34.500178   19.054159   50.229680
# 9720 2005-04-19 18:00:00  37.376234   20.634377   53.552780
# 9721 2005-04-19 19:00:00  40.920532   24.670542   58.297812

# %%
fig1 = model.plot(forecast)

# %%
fig2 = model.plot_components(forecast)

# %%
NewData['ds'].dtype
# Out:
# dtype('<M8[us]')

# %% [markdown]
# ### MultiVariate FB Prophet Analysis

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# 1. Prepare the Data
df = pd.DataFrame()
df['ds'] = NewData['ds'] 
df['y'] = AQI['C6H6(GT)']   # Target pollutant: Benzene
df['T'] = AQI['T']          # Regressor 1: Temperature
df['AH'] = AQI['AH']        # Regressor 2: Absolute Humidity
df['PT08.S2(NMHC)'] = AQI['PT08.S2(NMHC)']
df.head()
# Out:
#                    ds     y     T      AH  PT08.S2(NMHC)
# 0 2004-03-10 18:00:00  11.9  13.6  0.7578         1046.0
# 1 2004-03-10 19:00:00   9.4  13.3  0.7255          955.0
# 2 2004-03-10 20:00:00   9.0  11.9  0.7502          939.0
# 3 2004-03-10 21:00:00   9.2  11.0  0.7867          948.0
# 4 2004-03-10 22:00:00   6.5  11.2  0.7888          836.0

# %%
df.isnull().sum()
# Out:
# ds               0
# y                0
# T                0
# AH               0
# PT08.S2(NMHC)    0
# dtype: int64

# %%
# Chronological Train-Test Split (80% train, 20% test)
split_index = int(len(df) * 0.8)
train = df.iloc[:split_index].copy()
test = df.iloc[split_index:].copy()

# # Apply the log transform to the training target only
# train['y'] = np.log1p(train['y'])

# %%
# Initialize and Train
model = Prophet(yearly_seasonality=True, weekly_seasonality=True, daily_seasonality=True)
model.add_regressor('T')
model.add_regressor('AH')
model.fit(train)
# Out:
# Yearly seasonality is enabled with less than 730 days (approximately 2 years) of history. The model may be under-identified, and the trend/seasonality decomposition can be unstable and dependent on the Prophet/Stan version. Consider disabling yearly seasonality or providing more history.
# 14:18:29 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:30 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Predict on the Test Set
# The future dataframe must contain the timestamps AND regressor values
# future = test[['ds', 'T', 'AH']]
# forecast = model.predict(future)

 # New Predict on the Test Set
future = test[['ds', 'T', 'AH', 'PT08.S2(NMHC)']] 
forecast = model.predict(future)

# NEW: Reversing the log transform on predictions and confidence intervals
forecast['yhat'] = np.clip(forecast['yhat'])
forecast['yhat_lower'] = np.clip(forecast['yhat_lower'])
forecast['yhat_upper'] = np.clip(forecast['yhat_upper'])

# %%
y_true = test['y'].values
y_pred = forecast['yhat'].values

rmse = np.sqrt(mean_squared_error(y_true, y_pred))
print(f"RMSE: {rmse:.2f} microg/m^3")
# Out:
# RMSE: 10.02 microg/m^3

# %%
fig = model.plot(forecast)
plt.show()

# %%
fig2 = model.plot_components(forecast)

# %% [markdown]
# **Using XGBoost Instead to Get Better Result**

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# Feature Engineering: XGBoost doesn't need 'ds', but it loves 'hour'
df['Hour'] = df['ds'].dt.hour

# Define our inputs (X) and target (y)
features = ['T', 'AH', 'PT08.S2(NMHC)', 'Hour']
X = df[features]
y = df['y']

# 80/20 data Split
split_index = int(len(df) * 0.8)
X_train, X_test = X.iloc[:split_index], X.iloc[split_index:]
y_train, y_test = y.iloc[:split_index], y.iloc[split_index:]

# Train the XGBoost Model
xgb_model = XGBRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
xgb_model.fit(X_train, y_train)

# Predict and Evaluate
xgb_preds = xgb_model.predict(X_test)
xgb_preds = np.clip(xgb_preds, a_min=0, a_max=None) # Stop negative predictions just in case

rmse = np.sqrt(mean_squared_error(y_test, xgb_preds))
print(f"XGBoost RMSE: {rmse:.2f} microg/m^3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[243], line 1
# ----> 1 from xgboost import XGBRegressor
#       2 from sklearn.metrics import mean_squared_error
#       3
#       4 # Feature Engineering: XGBoost doesn't need 'ds', but it loves 'hour'
#
# ModuleNotFoundError: No module named 'xgboost'
# Task was destroyed but it is pending!
# task: <Task pending name='Task-1024' coro=<_async_in_context.<locals>.run_in_context() done, defined at B:\AQI Forecast\venv\Lib\site-packages\ipykernel\utils.py:57> wait_for=<Task pending name='Task-1025' coro=<Kernel.shell_main() running at B:\AQI Forecast\venv\Lib\site-packages\ipykernel\kernelbase.py:597> cb=[Task.task_wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at B:\AQI Forecast\venv\Lib\site-packages\zmq\eventloop\zmqstream.py:563]>
# ...
